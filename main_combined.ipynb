# %%
# !pip install -r requirements.txt
# !pip install easyocr
# Out:
# Requirement already satisfied: torch>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (2.6.0)
# Requirement already satisfied: transformers in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (4.51.1)
# Requirement already satisfied: Pillow in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (10.4.0)
# Requirement already satisfied: opencv-python in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (4.11.0.86)
# Requirement already satisfied: pyttsx3 in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (2.98)
# Requirement already satisfied: ultralytics in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (8.3.105)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (3.10.0)
# Requirement already satisfied: gtts in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 8)) (2.5.4)
# Requirement already satisfied: IPython in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 9)) (8.27.0)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 10)) (1.26.4)
# Requirement already satisfied: easyocr in c:\users\hp\anaconda3\lib\site-packages (from -r requirements.txt (line 11)) (1.7.2)
# Requirement already satisfied: filelock in c:\users\hp\anaconda3\lib\site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\hp\anaconda3\lib\site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (4.11.0)
# Requirement already satisfied: networkx in c:\users\hp\anaconda3\lib\site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\hp\anaconda3\lib\site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\hp\anaconda3\lib\site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\hp\anaconda3\lib\site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=2.0.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\users\hp\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 2)) (0.30.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 2)) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hp\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\hp\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 2)) (2024.9.11)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\hp\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 2)) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\hp\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\hp\anaconda3\lib\site-packages (from transformers->-r requirements.txt (line 2)) (4.66.5)
# Requirement already satisfied: comtypes in c:\users\hp\anaconda3\lib\site-packages (from pyttsx3->-r requirements.txt (line 5)) (1.4.10)
# Requirement already satisfied: pypiwin32 in c:\users\hp\anaconda3\lib\site-packages (from pyttsx3->-r requirements.txt (line 5)) (223)
# Requirement already satisfied: pywin32 in c:\users\hp\anaconda3\lib\site-packages (from pyttsx3->-r requirements.txt (line 5)) (305.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics->-r requirements.txt (line 6)) (1.13.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics->-r requirements.txt (line 6)) (0.21.0)
# Requirement already satisfied: psutil in c:\users\hp\anaconda3\lib\site-packages (from ultralytics->-r requirements.txt (line 6)) (5.9.0)
# Requirement already satisfied: py-cpuinfo in c:\users\hp\anaconda3\lib\site-packages (from ultralytics->-r requirements.txt (line 6)) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics->-r requirements.txt (line 6)) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics->-r requirements.txt (line 6)) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics->-r requirements.txt (line 6)) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: click<8.2,>=7.1 in c:\users\hp\anaconda3\lib\site-packages (from gtts->-r requirements.txt (line 8)) (8.1.7)
# Requirement already satisfied: decorator in c:\users\hp\anaconda3\lib\site-packages (from IPython->-r requirements.txt (line 9)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\anaconda3\lib\site-packages (from IPython->-r requirements.txt (line 9)) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\hp\anaconda3\lib\site-packages (from IPython->-r requirements.txt (line 9)) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\hp\anaconda3\lib\site-packages (from IPython->-r requirements.txt (line 9)) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hp\anaconda3\lib\site-packages (from IPython->-r requirements.txt (line 9)) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\hp\anaconda3\lib\site-packages (from IPython->-r requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\hp\anaconda3\lib\site-packages (from IPython->-r requirements.txt (line 9)) (5.14.3)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from IPython->-r requirements.txt (line 9)) (0.4.6)
# Requirement already satisfied: opencv-python-headless in c:\users\hp\anaconda3\lib\site-packages (from easyocr->-r requirements.txt (line 11)) (4.11.0.86)
# Requirement already satisfied: scikit-image in c:\users\hp\anaconda3\lib\site-packages (from easyocr->-r requirements.txt (line 11)) (0.24.0)
# Requirement already satisfied: python-bidi in c:\users\hp\anaconda3\lib\site-packages (from easyocr->-r requirements.txt (line 11)) (0.6.6)
# Requirement already satisfied: Shapely in c:\users\hp\anaconda3\lib\site-packages (from easyocr->-r requirements.txt (line 11)) (2.1.0)
# Requirement already satisfied: pyclipper in c:\users\hp\anaconda3\lib\site-packages (from easyocr->-r requirements.txt (line 11)) (1.3.0.post6)
# Requirement already satisfied: ninja in c:\users\hp\anaconda3\lib\site-packages (from easyocr->-r requirements.txt (line 11)) (1.11.1.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\hp\anaconda3\lib\site-packages (from jedi>=0.16->IPython->-r requirements.txt (line 9)) (0.8.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics->-r requirements.txt (line 6)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics->-r requirements.txt (line 6)) (2023.3)
# Requirement already satisfied: wcwidth in c:\users\hp\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython->-r requirements.txt (line 9)) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests->transformers->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests->transformers->-r requirements.txt (line 2)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests->transformers->-r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests->transformers->-r requirements.txt (line 2)) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from jinja2->torch>=2.0.0->-r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: imageio>=2.33 in c:\users\hp\anaconda3\lib\site-packages (from scikit-image->easyocr->-r requirements.txt (line 11)) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\hp\anaconda3\lib\site-packages (from scikit-image->easyocr->-r requirements.txt (line 11)) (2023.4.12)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\hp\anaconda3\lib\site-packages (from scikit-image->easyocr->-r requirements.txt (line 11)) (0.4)
# Requirement already satisfied: executing in c:\users\hp\anaconda3\lib\site-packages (from stack-data->IPython->-r requirements.txt (line 9)) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\hp\anaconda3\lib\site-packages (from stack-data->IPython->-r requirements.txt (line 9)) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\hp\anaconda3\lib\site-packages (from stack-data->IPython->-r requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: easyocr in c:\users\hp\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: torch in c:\users\hp\anaconda3\lib\site-packages (from easyocr) (2.6.0)
# Requirement already satisfied: torchvision>=0.5 in c:\users\hp\anaconda3\lib\site-packages (from easyocr) (0.21.0)
# Requirement already satisfied: opencv-python-headless in c:\users\hp\anaconda3\lib\site-packages (from easyocr) (4.11.0.86)
# Requirement already satisfied: scipy in c:\users\hp\anaconda3\lib\site-packages (from easyocr) (1.13.1)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from easyocr) (1.26.4)
# Requirement already satisfied: Pillow in c:\users\hp\anaconda3\lib\site-packages (from easyocr) (10.4.0)
# Requirement already satisfied: scikit-image in c:\users\hp\anaconda3\lib\site-packages (from easyocr) (0.24.0)
# Requirement already satisfied: python-bidi in c:\users\hp\anaconda3\lib\site-packages (from easyocr) (0.6.6)
# Requirement already satisfied: PyYAML in c:\users\hp\anaconda3\lib\site-packages (from easyocr) (6.0.1)
# Requirement already satisfied: Shapely in c:\users\hp\anaconda3\lib\site-packages (from easyocr) (2.1.0)
# Requirement already satisfied: pyclipper in c:\users\hp\anaconda3\lib\site-packages (from easyocr) (1.3.0.post6)
# Requirement already satisfied: ninja in c:\users\hp\anaconda3\lib\site-packages (from easyocr) (1.11.1.4)
# Requirement already satisfied: filelock in c:\users\hp\anaconda3\lib\site-packages (from torch->easyocr) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\hp\anaconda3\lib\site-packages (from torch->easyocr) (4.11.0)
# Requirement already satisfied: networkx in c:\users\hp\anaconda3\lib\site-packages (from torch->easyocr) (3.3)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from torch->easyocr) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\hp\anaconda3\lib\site-packages (from torch->easyocr) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\hp\anaconda3\lib\site-packages (from torch->easyocr) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\hp\anaconda3\lib\site-packages (from torch->easyocr) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\anaconda3\lib\site-packages (from sympy==1.13.1->torch->easyocr) (1.3.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\hp\anaconda3\lib\site-packages (from scikit-image->easyocr) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\hp\anaconda3\lib\site-packages (from scikit-image->easyocr) (2023.4.12)
# Requirement already satisfied: packaging>=21 in c:\users\hp\anaconda3\lib\site-packages (from scikit-image->easyocr) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\hp\anaconda3\lib\site-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from jinja2->torch->easyocr) (2.1.3)

# %%
from transformers import Blip2Processor, Blip2ForConditionalGeneration
import torch
from PIL import Image
import requests
import matplotlib.pyplot as plt

# %%
import sys
import os

# Add the main project directory to the Python path
sys.path.append(os.path.abspath("."))  # or the full path to your project folder

from modules.ocr_reader import read_text_combined
from modules.vlm_captioning import describe_scene
from modules.object_detection import detect_objects
from modules.audio_feedback import speak

def run_pipeline(image_path):
    print("🔍 Analyzing:", image_path)

    scene = describe_scene(image_path)
    objects = detect_objects(image_path)
    text = read_text_combined(image_path)

    print("\n🖼️ Scene:", scene)
    print("📦 Objects:", objects)
    print("📝 Text:", text)

    speak(f"I see {scene}. I detected the following objects: {', '.join(objects)}. The text says: {text}")

# Run the pipeline on an image
run_pipeline("sample_inputs/finalocr.jpeg")
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Config of the encoder: <class 'transformers.models.vit.modeling_vit.ViTModel'> is overwritten by shared encoder config: ViTConfig {
#   "attention_probs_dropout_prob": 0.0,
#   "encoder_stride": 16,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.0,
#   "hidden_size": 768,
#   "image_size": 384,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "model_type": "vit",
#   "num_attention_heads": 12,
#   "num_channels": 3,
#   "num_hidden_layers": 12,
#   "patch_size": 16,
#   "pooler_act": "tanh",
#   "pooler_output_size": 768,
#   "qkv_bias": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.51.1"
# }
#
# Config of the decoder: <class 'transformers.models.trocr.modeling_trocr.TrOCRForCausalLM'> is overwritten by shared decoder config: TrOCRConfig {
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_cross_attention": true,
#   "attention_dropout": 0.0,
#   "bos_token_id": 0,
#   "classifier_dropout": 0.0,
#   "cross_attention_hidden_size": 768,
#   "d_model": 1024,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 4096,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 12,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "eos_token_id": 2,
#   "init_std": 0.02,
#   "is_decoder": true,
#   "layernorm_embedding": true,
#   "max_position_embeddings": 512,
#   "model_type": "trocr",
#   "pad_token_id": 1,
#   "scale_embedding": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.51.1",
#   "use_cache": false,
#   "use_learned_position_embeddings": true,
#   "vocab_size": 50265
# }
#
# Some weights of VisionEncoderDecoderModel were not initialized from the model checkpoint at microsoft/trocr-base-printed and are newly initialized: ['encoder.pooler.dense.bias', 'encoder.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using CPU. Note: This module is much faster with a GPU.
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# 🔍 Analyzing: sample_inputs/finalocr.jpeg
#
# image 1/1 C:\Users\hp\Desktop\yash\ai_assist_vision\sample_inputs\finalocr.jpeg: 384x640 1 person, 1 cup, 1 tv, 2 laptops, 1 mouse, 1 keyboard, 46.8ms
# Speed: 1.8ms preprocess, 46.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 🔍 Performing OCR with TrOCR and EasyOCR...
#
# 🖼️ Scene: a woman sitting at a desk with a book and a computer
# 📦 Objects: ['person', 'cup', 'laptop', 'mouse', 'keyboard', 'tv']
# 📝 Text: ITEM. I At Gidep Yiqui AF 467
#
# 🔊 Speaking...
